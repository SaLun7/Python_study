# %%
# 함수만들기

def hello():
    print("Hello world")

hello()
# Out:
# Hello world

# %%
hello2()

def hello2():
    print("Hello World!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 hello2()
#       2
#       3 def hello2():
#       4     print("Hello World!")
#
# NameError: name 'hello2' is not defined

# %%
# 덧셈함수 만들기

def add(a, b):
    """
    메개변수
    a : int
    b : int

    출력 : int
    """
    print(a + b)

add(10, 20)
# Out:
# 30

# %%
add.__doc__
# Out:
# '\n메개변수\na : int\nb : int\n\n출력 : int\n'
