# %%
hello = "hello world"
print(hello)
# Out:
# hello world

# %%
hello = "안녕하세요"
print(hello)
# Out:
# 안녕하세요

# %%
hello = '''hello, world'''
print(hello)
# Out:
# hello, world

# %%
# 여러줄로 된 문자열 사용하기
hello = '''hello, world
안녕하세요
Python입니다.'''

print(hello)
# Out:
# hello, world
# 안녕하세요
# Python입니다.

# %%
# 문자열 안에 작은따옴표나 큰따옴표 포함하기
s = "Python isn't difficult"
print(s)
# Out:
# Python isn't difficult

# %%
s = 'Python isn't difficult'
print(s)
# Out:
#   Cell In[11], line 1
#     s = 'Python isn't difficult'
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
s = """Python is a programming languague that lets you work quickly
and
integrate systems more effectively."""

print(s)
# Out:
# Python is a programming languague that lets you work quickly
# and
# integrate systems more effectively.

# %%
s = """'Python' is a "programming language"
that lets you work quickly
and
integrate systems more effectively."""

print(s)
# Out:
# 'Python' is a "programming language"
# that lets you work quickly
# and
# integrate systems more effectively.
